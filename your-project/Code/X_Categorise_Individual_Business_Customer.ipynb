# %% [markdown]
# # Criteria to Determine if Customer is An Individual or Business/ Organisation
#
# The recommender system is going to work best when seperating individuals from businesses given that businesses are likely to be less persuaded with retargeting and other digital ad campaigns.

# %%
#Libraries
#Dataframe and arrays
import pandas as pd
import numpy as np

import matplotlib as plt

# %%
#make sure the clean file is passed in. 
df = pd.read_excel('../data/online_fashion.xlsx')

# %%
df['Rev'] = df['Quantity']* df['UnitPrice']

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.dropna(subset=['CustomerID'],inplace=True)
df_new.dropna(subset=['CustomerID'],inplace=True)
# Out:
# C:\Users\ellio\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_new.sort_values(by='UnitPrice', ascending=False)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 222682    556446     22502       PICNIC BASKET WICKER 60 PIECES         1
# 222680    556444     22502       PICNIC BASKET WICKER 60 PIECES        60
# 36165    C539438     22655          VINTAGE RED KITCHEN CABINET        -1
# 82768     543253     22655          VINTAGE RED KITCHEN CABINET         1
# 4989      536835     22655          VINTAGE RED KITCHEN CABINET         1
# 205759    554836     22655          VINTAGE RED KITCHEN CABINET         1
# 171178    551393     22656         VINTAGE BLUE KITCHEN CABINET         1
# 87141    C543632     22655          VINTAGE RED KITCHEN CABINET        -1
# 51636     540647     22655          VINTAGE RED KITCHEN CABINET         1
# 118769    546480     22656         VINTAGE BLUE KITCHEN CABINET         1
# 32484     539080     22655          VINTAGE RED KITCHEN CABINET         1
# 133994    547814     22656         VINTAGE BLUE KITCHEN CABINET         1
# ...

# %%
#Any customer buying over 2500 worth of goods should be categorised as business

# %%
df_cust_value = df.groupby('CustomerID').agg({'Rev': ['sum']}).sort_values(by=[('Rev','sum')], ascending=False) #nested column names
df_cust_value.reset_index(inplace=True)
df_cust_value.columns = ['CustomerID','TotalRev']
df_cust_value.head()
# Out:
#    CustomerID   TotalRev
# 0     14646.0  279489.02
# 1     18102.0  256438.49
# 2     17450.0  187482.17
# 3     14911.0  132572.62
# 4     12415.0  123725.45

# %%
df_cust_value.loc[(df_cust_value['TotalRev'] < 2500) & (df_cust_value['TotalRev'] > 0)]

#df.loc[(df['column_name'] >= A) & (df['column_name'] <= B)]
# Out:
#       CustomerID      TotalRev
# 682      16477.0  2.494460e+03
# 683      14546.0  2.487020e+03
# 684      14701.0  2.486220e+03
# 685      15271.0  2.485820e+03
# 686      12913.0  2.483630e+03
# 687      16710.0  2.483040e+03
# 688      13507.0  2.479160e+03
# 689      12455.0  2.466860e+03
# 690      17164.0  2.466400e+03
# 691      12517.0  2.464890e+03
# 692      17131.0  2.463170e+03
# 693      13784.0  2.462790e+03
# 694      15932.0  2.461850e+03
# 695      17682.0  2.459330e+03
# 696      14315.0  2.456980e+03
# 697      14842.0  2.456800e+03
# 698      14659.0  2.456530e+03
# 699      15750.0  2.451230e+03
# 700      14163.0  2.445910e+03
# 701      13588.0  2.445120e+03
# 702      13949.0  2.427320e+03
# 703      14766.0  2.423070e+03
# 704      15606.0  2.422640e+03
# 705      13658.0  2.421470e+03
# 706      15089.0  2.420840e+03
# 707      16143.0  2.419840e+03
# 708      12397.0  2.409900e+03
# 709      17589.0  2.404170e+03
# 710      15980.0  2.398860e+03
# ...

# %%
###Identify customers spending over 2500 - DONE

# %%
df_cust_items = df.groupby('CustomerID').agg({'Quantity': ['sum']}).sort_values(by=[('Quantity','sum')], ascending=False) #nested column names
df_cust_items.reset_index(inplace=True)
df_cust_items.columns = ['CustomerID','TotalNoItem']
df_cust_items.head()
# Out:
#    CustomerID  TotalNoItem
# 0     14646.0       196719
# 1     12415.0        77242
# 2     14911.0        77180
# 3     17450.0        69029
# 4     18102.0        64122

# %%
df_cust_items.loc[(df_cust_items['TotalNoItem'] < 60) & (df_cust_items['TotalNoItem'] > 0)].head()
# Out:
#       CustomerID  TotalNoItem
# 4018     16665.0           59
# 4019     14437.0           59
# 4020     16828.0           59
# 4021     15438.0           59
# 4022     15100.0           58

# %%
df_cust_items.loc[(df_cust_items['TotalNoItem'] > 60)]
# Out:
#       CustomerID  TotalNoItem
# 0        14646.0       196719
# 1        12415.0        77242
# 2        14911.0        77180
# 3        17450.0        69029
# 4        18102.0        64122
# 5        17511.0        63012
# 6        13694.0        61803
# 7        14298.0        58021
# 8        14156.0        57025
# 9        16684.0        49390
# 10       15311.0        37720
# 11       16422.0        32592
# 12       17404.0        32324
# 13       16333.0        32184
# 14       16029.0        32148
# 15       13089.0        30787
# 16       15061.0        28590
# 17       15769.0        27660
# 18       17949.0        27571
# 19       17381.0        25646
# 20       12748.0        24210
# 21       13798.0        23514
# 22       12931.0        23377
# 23       17841.0        22865
# 24       12901.0        20915
# 25       17857.0        19086
# 26       13081.0        19021
# 27       13027.0        17280
# 28       14096.0        16335
# 29       13408.0        16119
# ...

# %%
df_new.sort_values(by='UnitPrice', ascending=False)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 222680    556444     22502       PICNIC BASKET WICKER 60 PIECES        60
# 222682    556446     22502       PICNIC BASKET WICKER 60 PIECES         1
# 82768     543253     22655          VINTAGE RED KITCHEN CABINET         1
# 36165    C539438     22655          VINTAGE RED KITCHEN CABINET        -1
# 171178    551393     22656         VINTAGE BLUE KITCHEN CABINET         1
# 118769    546480     22656         VINTAGE BLUE KITCHEN CABINET         1
# 87141    C543632     22655          VINTAGE RED KITCHEN CABINET        -1
# 205759    554836     22655          VINTAGE RED KITCHEN CABINET         1
# 51636     540647     22655          VINTAGE RED KITCHEN CABINET         1
# 4989      536835     22655          VINTAGE RED KITCHEN CABINET         1
# 133994    547814     22656         VINTAGE BLUE KITCHEN CABINET         1
# 32484     539080     22655          VINTAGE RED KITCHEN CABINET         1
# ...
